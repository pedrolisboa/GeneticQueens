# %%
from viz import draw_chessboard
import matplotlib.pyplot as plt

# Example usage
n = 8
queens_positions = [4, 6, 1, 5, 7, 3, 0, 2]

fig, ax = plt.subplots(figsize=(5,5))
draw_chessboard(n, queens_positions, ax)
